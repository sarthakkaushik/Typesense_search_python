# %%
import json

# Your KPI dictionary
kpi_dict = {
    "Revenue": ["revenue","Actual sales", "Total sales", "sales", "Turnover","selling","top","Performance", "performance", "performing","NBA","NBP"],
    "Achievement": ["Achievement %", "Achievement percentage", "achieving", "achievement percent", 
                    "Performance", "performance", "performing"],
    "PY numbers": ["Previous Year", "Last year", "PY","Performance", "performance", "performing"],
    "Performance": ["Performance", "performance", "performing"],
    "Growth": ["Growing", "growth %", "growth percentage", "growth percent", "contracted", "grown","Performance", "performance", "performing"],
    "FY": ["FY","Financial Year", "Fiscal Year","202"],
    "Vertical wise": ["Vertical"],
    "Per pill price": ["per pill"],
    "Average Realization": ["realization"],
    "Budget": ["budget value","NBA","NBP","budget"],
    "Latest Estimate": ["Latest Estimate", "Estimate","LE","Latest"],
    "KPIs": ["KPI"],
    "Dominant": ["dominant"],
    "Market Share": ["market", "rank", "share"],
    "Product Names": ["Products", "Names"],
    "Q1": ["Quarter", "Q4", "Q3 FY24", "First quarter","Q"],
    "India": ["India", "INDIA","india"],
    "GGINDIA": ["GGI", "GGINDIA","GG","NBA","NBP","BU"],
    "YTD": ["YTD", "Year till date"],
    "CAGR": ["cagr"],
    "Dominant": ["Dominant"],
    "Trend": ["Trend"],
    "Rank": ["Rank", "rank"],
    "MAT": ["MAT","mat","moving annual total"],
    "MQT": ["MQT", "mqt","moving quarterly total"],
    "Market Growth": ["Market growth","Growth of market"],
    "Dosage form": ["Dosage Type","Dosage","dosage type","Dosage type"],
    "Corporations": ["Corporation","Company","companies","corporations","competetors"],
    "Sales Date": ["date","daily","day","daylevel"],
    "Plant Code":["plant","plant id", "plant code"],
    "BU_SKU_ID":["Vertical","brand","channel","product names","dosage form","divison","SKU","SKU ID","Product ID"," "],
    "Region": ["region", "territory"],
    "Sales Quantity in Packs": ["quantity in packs", "packs sold"],
    "Latest Estimate Quantity": ["latest estimate qty", "latest estimate quantity", "LE qty", "LE quantity", "estimated quantity"],
    "Budget Quantity": ["budget qty", "budget quantity"],
    "Reporting month": ["Q1", "Q2", "Q3","Q4","FY","YOY","QoQ","reporting month", "month for reporting", "reporting period","NBA","NBP"],
    "Channel": ["channel", "product channel"],
    "Customer": ["customer", "enterprise customer", "customer group"],
    "Sales Quantity": ["quantity","volume" "quantity sold", "quantity units", "sold quantity"],
    "Brand": ["brand", "product brand","brand wise"],
    "Vertical": ["vertical","vertical wise", "business vertical"],
    "Division": ["division", "business division"],
    "Product Name": ["product", "product description", "product title"],
    "BU": ["business unit", "BU", "unit","country","countries","NBA","NBP"],
    "CORPORATION_NEW": ["corporation", "company", "enterprise"],
    "a": ["data set", "dataset", "sales dataset"],
    "Molecule": ["molecule"],
    "DRL":["DRL","reddys"],
    "YoY":["yoy","Year on Year"],
    "QoQ":["qoq","Quarter on Quarter"],
    "New Product":["New","Product","launched","latest","new product"],
    "LAUNCH_FY":["Launch","Release","Launching year","new product"],
    "Discount %":["discounted","discount %","discounts"],
    "FTS":["fts"],
    "Pack Size" : ["Packsize","Pack size","Pack","size"],
    "NAG": ["NAG","NBA","NBP","BU"],
    "EUG": ["EUG","NBA","NBP","BU"],
    "Segment": ["Segment"],
    "Product Group": ["Product Group","Group"],
    "Therapy Area": ["therapy","therapywise","area"],
    "IQVIA": ["IQVIA","market data"],
    "Licensing": ["Licensing","Manufacturing source","mfg source"],
    "Net sales plus cutoff": ["cutoff","net sales plus cutoff","cut"],
    "Non discounted GTN %": ["Non discounted GTN %"],
    "discounted GTN %": ["discounted GTN %"],
    "Gross to net %": ["Gross to net %","GTN %"],
    "Launch Date": ["Launch","New","launch date","NBA","NBP"],
    "Planned Launch FY": ["Planned", "Planned launch","NBA","NBP","new"],
    "Planned Launch Date": ["Planned","new"],
    "NBA":["NBA","NBP"],
    "Institution": ["Institution"],
    "Billing type": ["Billing type"],
    "Returns %": ["Returns %"],
    "Gross Sales": ["Gross"],
    "Strength": ["Strength"],
    "Country":["country","countries"], #added for ambiguity check, not included in json schema
    "Local currency":["local","currency"], #added for ambiguity check, not included in json schema
    "INR":["inr","rupees","rupee"], #added for ambiguity check, not included in json schema
    "USD":["usd","dollar","dollars"], #added for ambiguity check, not included in json schema
    "USA":["US","USA","United States"], #added for ambiguity check, not included in json schema
    "Primary sales":["primary sales","primary"], #added for ambiguity check, not included in json schema
    "Secondary sales":["secondary sales","sales","secondary"] #added for ambiguity check, not included in json schema
}

# Output path
output_file = "kpi_synonyms.jsonl"

with open(output_file, "w", encoding="utf-8") as f:
    sort_order = 1
    for kpi, synonyms in kpi_dict.items():
        for synonym in synonyms:
            entry = {
                "kpi": kpi,
                "synonym": synonym,
                # Add sort_order field for sorting in tysense
                "sort_order": sort_order
            }
            sort_order += 1
            f.write(json.dumps(entry) + "\n")

print(f"✅ JSONL file created: {output_file}")
# Out:
# ✅ JSONL file created: kpi_synonyms.jsonl
